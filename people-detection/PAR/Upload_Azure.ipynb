# %%
#터미널에서 설치
#pip install azure-cognitiveservices-vision-customvision
#pip install pylabel

# %%
#Import Azure cognitive services libraries 
from azure.cognitiveservices.vision.customvision.training import CustomVisionTrainingClient
from azure.cognitiveservices.vision.customvision.prediction import CustomVisionPredictionClient
from azure.cognitiveservices.vision.customvision.training.models import ImageFileCreateBatch, ImageFileCreateEntry, Region
from msrest.authentication import ApiKeyCredentials

import os, zipfile
from pathlib import PurePath
from os.path import exists
from decimal import *

from pylabel import importer

# %%
ENDPOINT = "Endpoint"
training_key = "Training Key"
prediction_key = "Training Key와 동일"
prediction_resource_id = "구독 ID"

# %%
#Initialize objects used by Azure Congitive vision
credentials = ApiKeyCredentials(in_headers={"Training-key": training_key})
trainer = CustomVisionTrainingClient(ENDPOINT, credentials)
prediction_credentials = ApiKeyCredentials(in_headers={"Prediction-key": prediction_key})
predictor = CustomVisionPredictionClient(ENDPOINT, prediction_credentials)

#Create a new project
publish_iteration_name = "Classification_Model"
obj_detection_domain = next(domain for domain in trainer.get_domains() if domain.type == "Classification" and domain.name == "General")
project = trainer.create_project("Team5", domain_id=obj_detection_domain.id)
#If you browse to https://www.customvision.ai/ you should see a new project called "PyLabel Sample Dataset"

# %%
import os
from torchvision import datasets, transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import pandas as pd

class MultiLabelImageDataset(Dataset):
    def __init__(self, csv_file, img_dir, transform=None):
        self.labels_frame = pd.read_csv(csv_file)
        self.img_dir = img_dir
        self.transform = transform
        self.classes = ['male', 'female', 'old', 'adult', 'young']

    def __len__(self):
        return len(self.labels_frame)

    def __getitem__(self, idx):
        img_name = os.path.join(self.img_dir, self.labels_frame.iloc[idx, 0])
        image = Image.open(img_name).convert('RGB')
        
        labels = self.labels_frame.iloc[idx, 1:].values.astype('float')
        
        if self.transform:
            image = self.transform(image)

        return image, labels

# 데이터 변환 정의
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# 데이터셋 생성
dataset = MultiLabelImageDataset(csv_file='dataset/gender_age_label_df.csv',
                                 img_dir='dataset/Image',
                                 transform=transform)

# DataLoader 생성
dataloader = DataLoader(dataset, batch_size=32, shuffle=True, num_workers=4)

# %%
project_id = "Project ID"

# 인증 설정
credentials = ApiKeyCredentials(in_headers={"Training-key": training_key})
trainer = CustomVisionTrainingClient(ENDPOINT, credentials)

# 생성할 태그 정의
gender_tags = ['male', 'female']
age_class_tags = ['old', 'adult', 'young']

# 기존 태그 확인
existing_tags = trainer.get_tags(project_id)
existing_tag_dict = {tag.name: tag.id for tag in existing_tags}

# 태그 생성 함수
def get_or_create_tag(trainer, project_id, tag_name, existing_tags):
    if tag_name in existing_tags:
        return existing_tags[tag_name]
    else:
        new_tag = trainer.create_tag(project_id, tag_name)
        return new_tag.id

# gender와 age_class 태그 생성
gender_tag_ids = {}
age_class_tag_ids = {}

# gender 태그 생성
for gender in gender_tags:
    gender_tag_ids[gender] = get_or_create_tag(trainer, project_id, gender, existing_tag_dict)

# age_class 태그 생성
for age_class in age_class_tags:
    age_class_tag_ids[age_class] = get_or_create_tag(trainer, project_id, age_class, existing_tag_dict)

# %%
# Azure Custom Vision 설정
project_id = "Project ID"

# 인증 설정
credentials = ApiKeyCredentials(in_headers={"Training-key": training_key})
trainer = CustomVisionTrainingClient(ENDPOINT, credentials)

# CSV 파일 읽기
csv_path = 'dataset/gender_age_label_df.csv'
dataset_df = pd.read_csv(csv_path)

# 기존 태그 가져오기
existing_tags = trainer.get_tags(project_id)
existing_tag_dict = {tag.name: tag.id for tag in existing_tags}

# 이미지 리스트 생성 및 태그 자동 레이블링
image_list = []
for _, row in dataset_df.iterrows():
    img_filename = row['img_filename']
    image_path = f"dataset/Image/{img_filename}"
    
    # 해당 이미지의 태그 ID 리스트 생성
    tag_ids = [
        existing_tag_dict[row['gender']],      # gender 태그
        existing_tag_dict[row['age_class']]    # age_class 태그
    ]
    
    try:
        with open(image_path, "rb") as image_contents:
            image_list.append(
                ImageFileCreateEntry(
                    name=img_filename,
                    contents=image_contents.read(),
                    tag_ids=tag_ids
                )
            )
    except FileNotFoundError:
        print(f"이미지를 찾을 수 없습니다: {image_path}")

# 배치 업로드 함수
def upload_images(trainer, project_id, image_batch):
    try:
        upload_result = trainer.create_images_from_files(
            project_id,
            ImageFileCreateBatch(images=image_batch)
        )
        
        if not upload_result.is_batch_successful:
            print("이미지 배치 업로드에 실패했습니다.")
            for image in upload_result.images:
                print(f"이미지: {image.source_url}, 상태: {image.status}")
                if image.status == "OKDuplicate":
                    print("중복 이미지입니다. 이미 프로젝트에 존재합니다.")
                elif image.status != "OK":
                    print(f"업로드 실패 이유: {image.status}")
        else:
            print(f"{len(image_batch)}개 이미지가 성공적으로 업로드되었습니다.")
    except Exception as e:
        print(f"업로드 중 오류 발생: {str(e)}")

# 배치 크기 설정 (Azure의 제한으로 인해 64개씩 처리)
BATCH_SIZE = 64

# 배치 단위로 이미지 업로드
for i in range(0, len(image_list), BATCH_SIZE):
    batch = image_list[i:i + BATCH_SIZE]
    upload_images(trainer, project_id, batch)
# Out:
# 이미지 배치 업로드에 실패했습니다.
# 이미지: IN_H00276_SN1_090405_15487.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15439.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15457.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15484.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15478.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15451.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15436.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15430.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17306.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15472.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17303.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15427.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15460.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15445.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15415.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15403.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17309.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15466.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15463.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15421.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15442.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34069.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15406.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34084.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34078.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15475.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15448.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15424.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15454.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34045.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17300.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15409.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15400.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34075.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34066.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34051.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34030.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34027.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34024.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15412.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34057.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34054.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34042.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34039.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34018.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34087.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34015.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34012.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15481.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34063.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34072.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34048.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34033.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34009.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15469.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34081.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34036.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34021.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34006.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15433.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090405_15418.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34003.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34060.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090402_34000.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지 배치 업로드에 실패했습니다.
# 이미지: IN_H00276_SN1_090410_15304.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15310.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15298.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14905.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14896.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14887.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15316.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14902.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14860.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14878.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17384.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14830.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17369.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14890.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14866.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14863.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14851.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17378.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14893.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14836.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17372.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14908.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14833.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17354.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15313.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15295.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17366.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17345.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14917.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17381.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17375.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17348.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17339.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14911.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14899.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14872.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14839.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17336.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15307.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14869.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14875.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14884.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17333.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14845.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17327.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14854.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14848.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14842.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17363.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17360.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17321.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17357.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17351.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17342.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17330.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17324.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17318.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14914.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15301.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14881.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090409_14857.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17387.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17315.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090408_17312.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지 배치 업로드에 실패했습니다.
# 이미지: IN_H00276_SN1_090411_25668.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25677.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25665.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25674.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25659.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25647.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25632.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25620.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25611.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090401_8432.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25617.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15379.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090401_8441.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25686.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25626.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25635.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15373.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090401_8465.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090401_8453.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25608.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15361.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15355.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15370.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090401_8450.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25683.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25662.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25641.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25614.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15382.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15376.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15352.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15340.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090401_8459.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090401_8447.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090401_8444.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25656.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25629.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25623.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15349.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090401_8462.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25689.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25680.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25605.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15367.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15343.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090401_8435.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25653.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15358.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15331.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090401_8438.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25650.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15337.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15334.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15328.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15364.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15346.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15325.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15322.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25692.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090401_8456.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25644.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25671.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090411_25638.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00276_SN1_090410_15319.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지 배치 업로드에 실패했습니다.
# 이미지: IN_H00277_SN1_090402_33091.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090402_33076.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090402_33079.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090402_33061.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090404_8452.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090404_8449.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090404_8437.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090404_8419.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090404_8413.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090402_33082.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090402_33085.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090402_33073.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090402_33058.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090402_33112.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090402_33109.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090402_33118.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090402_33046.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090402_33043.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090401_8510.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090404_8443.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090404_8428.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090402_33100.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090401_8501.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090402_33097.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090402_33106.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090402_33094.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090402_33088.png, 상태: OKDuplicate
# 중복 이미지입니다. 이미 프로젝트에 존재합니다.
# 이미지: IN_H00277_SN1_090402_